# %%
# import the library
# %matplotlib inline

import pandas as pd
import numpy as np
import collections
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances

sns.set_style('whitegrid')

# %% [markdown]
# # Problem definition

# %% [markdown]
# Cluster counties based on demographic and economic data
#
# https://www.kaggle.com/muonneutrino/us-census-demographic-data/data

# %% [markdown]
# # Load the data

# %%
#input
df = pd.read_csv('data/acs2015_county_data.csv')
df = df.set_index(['CensusId', 'State', 'County'])
df.head()
# Out:
#                           TotalPop    Men  Women  Hispanic  White  Black  \
# CensusId State   County
# 1001     Alabama Autauga     55221  26745  28476       2.6   75.8   18.5
# 1003     Alabama Baldwin    195121  95314  99807       4.5   83.1    9.5
# 1005     Alabama Barbour     26932  14497  12435       4.6   46.2   46.7
# 1007     Alabama Bibb        22604  12073  10531       2.2   74.5   21.4
# 1009     Alabama Blount      57710  28512  29198       8.6   87.9    1.5
#
#                           Native  Asian  Pacific  Citizen      ...       Walk  \
# CensusId State   County                                        ...
# 1001     Alabama Autauga     0.4    1.0      0.0    40725      ...        0.5
# 1003     Alabama Baldwin     0.6    0.7      0.0   147695      ...        1.0
# 1005     Alabama Barbour     0.2    0.4      0.0    20714      ...        1.8
# 1007     Alabama Bibb        0.4    0.1      0.0    17495      ...        0.6
# 1009     Alabama Blount      0.3    0.1      0.0    42345      ...        0.9
#
#                           OtherTransp  WorkAtHome  MeanCommute  Employed  \
# CensusId State   County
# 1001     Alabama Autauga          1.3         1.8         26.5     23986
# 1003     Alabama Baldwin          1.4         3.9         26.4     85953
# 1005     Alabama Barbour          1.5         1.6         24.1      8597
# 1007     Alabama Bibb             1.5         0.7         28.8      8294
# 1009     Alabama Blount           0.4         2.3         34.9     22189
#
#                           PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# CensusId State   County
# 1001     Alabama Autauga         73.6        20.9           5.5         0.0
# 1003     Alabama Baldwin         81.5        12.3           5.8         0.4
# 1005     Alabama Barbour         71.8        20.8           7.3         0.1
# 1007     Alabama Bibb            76.8        16.1           6.7         0.4
# 1009     Alabama Blount          82.0        13.5           4.2         0.4
#
#                           Unemployment
# CensusId State   County
# 1001     Alabama Autauga           7.6
# 1003     Alabama Baldwin           7.5
# 1005     Alabama Barbour          17.6
# 1007     Alabama Bibb              8.3
# 1009     Alabama Blount            7.7
#
# [5 rows x 34 columns]

# %% [markdown]
# # Feature Engineering

# %%
# remove NaNs
df = df.dropna()

# remove column
X_columns = list(df.columns)
if 'IncomeErr' in X_columns:
    X_columns.remove('IncomeErr')
if 'IncomePerCapErr' in X_columns:
    X_columns.remove('IncomePerCapErr')
df = df[X_columns]

# normalize the columns
df_norm = df.copy()
for col in X_columns:
    df_norm[col] = StandardScaler().fit_transform(df_norm[col].values.reshape(-1, 1))

print(df.shape)
df_norm.head()
# Out:
# (3218, 32)
# /Users/arybressane/anaconda/envs/py3/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
#                           TotalPop       Men     Women  Hispanic     White  \
# CensusId State   County
# 1001     Alabama Autauga -0.138565 -0.141558 -0.135649 -0.436917  0.015217
# 1003     Alabama Baldwin  0.299519  0.296021  0.302818 -0.338162  0.333734
# 1005     Alabama Barbour -0.227149 -0.219720 -0.234253 -0.332964 -1.276304
# 1007     Alabama Bibb    -0.240702 -0.235189 -0.245956 -0.457708 -0.041505
# 1009     Alabama Blount  -0.130771 -0.130282 -0.131211 -0.125057  0.543170
#
#                              Black    Native     Asian   Pacific   Citizen  \
# CensusId State   County
# 1001     Alabama Autauga  0.688328 -0.182113 -0.085542 -0.182552 -0.142600
# 1003     Alabama Baldwin  0.058063 -0.154533 -0.200496 -0.182552  0.378840
# 1005     Alabama Barbour  2.663158 -0.209694 -0.315449 -0.182552 -0.240147
# 1007     Alabama Bibb     0.891413 -0.182113 -0.430402 -0.182552 -0.255838
# 1009     Alabama Blount  -0.502173 -0.195903 -0.430402 -0.182552 -0.134703
#
#                               ...           Walk  OtherTransp  WorkAtHome  \
# CensusId State   County       ...
# 1001     Alabama Autauga      ...      -0.759868    -0.186826   -0.891579
# 1003     Alabama Baldwin      ...      -0.624686    -0.126385   -0.229682
# 1005     Alabama Barbour      ...      -0.408394    -0.065944   -0.954617
# 1007     Alabama Bibb         ...      -0.732831    -0.065944   -1.238287
# 1009     Alabama Blount       ...      -0.651722    -0.730796   -0.733985
#
#                           MeanCommute  Employed  PrivateWork  PublicWork  \
# CensusId State   County
# 1001     Alabama Autauga     0.574999 -0.144510    -0.081324    0.519837
# 1003     Alabama Baldwin     0.557128  0.269380     0.929400   -0.812026
# 1005     Alabama Barbour     0.146099 -0.247296    -0.311616    0.504350
# 1007     Alabama Bibb        0.986028 -0.249320     0.328083   -0.223528
# 1009     Alabama Blount      2.076149 -0.156513     0.993370   -0.626184
#
#                           SelfEmployed  FamilyWork  Unemployment
# CensusId State   County
# 1001     Alabama Autauga     -0.621632   -0.633383     -0.120902
# 1003     Alabama Baldwin     -0.544978    0.245447     -0.145337
# 1005     Alabama Barbour     -0.161703   -0.413675      2.322651
# 1007     Alabama Bibb        -0.315013    0.245447      0.050147
# 1009     Alabama Blount      -0.953804    0.245447     -0.096466
#
# [5 rows x 32 columns]

# %% [markdown]
# # Model Training

# %%
k = 7
kmeans = KMeans(n_clusters=k).fit(df_norm.values)

print(set(kmeans.labels_))
print(collections.Counter(kmeans.labels_))

df_results = df.copy()
df_norm['cluster'] = kmeans.labels_
df_results['cluster'] = kmeans.labels_
# Out:
# {0, 1, 2, 3, 4, 5, 6}
# Counter({5: 1240, 2: 740, 1: 505, 3: 478, 0: 122, 6: 97, 4: 36})

# %%
# Analyze the results
df_results = df_results.reset_index()
for cluster in sorted(set(kmeans.labels_)):
    print(collections.Counter(df_results[df_results['cluster']==cluster]['State']).most_common(5))

n_clusters = len(set(kmeans.labels_))
for col in X_columns:
    print(col)
    i = 1
    plt.figure(figsize=(16,3))
    for cluster in sorted(set(kmeans.labels_)):
        plt.subplot(1, n_clusters, i)
        plt.xlim([0,df_results[col].max()])
        plt.hist(df_results[df_results['cluster']==cluster][col], label=str(cluster), alpha=0.3, bins=20)
        i += 1
    plt.show()
# Out:
# [('California', 15), ('New Jersey', 11), ('New York', 10), ('Texas', 8), ('Florida', 7)]
# [('Virginia', 46), ('Florida', 24), ('Texas', 23), ('New York', 20), ('Minnesota', 19)]
# [('Georgia', 103), ('Texas', 87), ('Mississippi', 68), ('Louisiana', 48), ('North Carolina', 47)]
# [('Nebraska', 58), ('Kansas', 54), ('Montana', 42), ('South Dakota', 42), ('Texas', 39)]
# [('Alaska', 13), ('South Dakota', 9), ('Montana', 4), ('North Dakota', 3), ('Arizona', 2)]
# [('Texas', 83), ('Missouri', 78), ('Indiana', 77), ('Illinois', 75), ('Kentucky', 72)]
# [('Puerto Rico', 78), ('Texas', 13), ('New Mexico', 4), ('Arizona', 1), ('California', 1)]
# TotalPop
# Men
# Women
# Hispanic
# White
# Black
# Native
# Asian
# Pacific
# Citizen
# Income
# IncomePerCap
# Poverty
# ChildPoverty
# Professional
# Service
# Office
# Construction
# Production
# Drive
# Carpool
# Transit
# Walk
# OtherTransp
# WorkAtHome
# MeanCommute
# Employed
# PrivateWork
# PublicWork
# SelfEmployed
# FamilyWork
# Unemployment

# %%
# Analyze the centroids
df_results.groupby('cluster').mean().round(2).T
# Out:
# cluster                0          1         2         3         4         5  \
# CensusId        27896.85   31237.99  27961.06  31349.58  23979.61  31375.79
# TotalPop      1161280.30  171486.74  39226.98   9277.35  13381.06  41338.85
# Men            567970.04   84335.04  19516.21   4708.55   6749.64  20510.09
# Women          593310.25   87151.69  19710.77   4568.79   6631.42  20828.76
# Hispanic           18.94       7.78     10.81      8.25      4.25      6.24
# White              53.01      79.49     61.33     86.04     27.87     87.41
# Black              15.18       7.53     23.89      0.99      0.78      3.27
# Native              0.31       0.63      1.47      2.20     59.48      0.71
# Asian               8.87       2.26      0.69      0.65      2.79      0.63
# Pacific             0.44       0.07      0.05      0.08      0.41      0.04
# Citizen        772432.11  125557.84  28249.54   7100.94   9041.44  31107.25
# Income          66291.70   60815.65  36361.32  47560.66  43121.56  45491.42
# IncomePerCap    34287.90   30366.24  19261.27  26328.79  19321.56  23420.33
# Poverty            13.70      11.73     23.74     13.31     28.86     15.56
# ChildPoverty       19.13      15.32     34.25     17.39     37.42     22.01
# Professional       41.45      37.49     26.84     34.89     34.20     28.41
# Service            17.72      17.24     20.06     17.46     20.11     17.78
# Office             23.97      24.40     21.83     19.54     19.07     22.28
# Construction        7.23       9.49     13.89     16.12     14.10     12.58
# Production          9.62      11.38     17.39     11.98     12.52     18.95
# Drive              72.05      80.95     81.09     71.68     53.52     81.46
# Carpool             9.15       8.99     11.54     10.25     10.97     10.27
# Transit             9.06       1.38      0.54      0.55      0.97      0.43
# Walk                3.08       2.41      2.21      6.71     18.34      2.58
# OtherTransp         1.94       1.59      1.67      1.77      7.23      1.32
# WorkAtHome          4.71       4.67      2.95      9.04      8.98      3.95
# MeanCommute        28.24      24.74     24.62     18.68     14.13     23.14
# Employed       554019.50   81654.19  15193.81   4212.67   4321.83  18049.70
# PrivateWork        80.30      77.88     72.98     65.09     49.76     77.82
# PublicWork         14.01      15.93     20.30     20.11     40.80     14.57
# SelfEmployed        5.56       6.04      6.51     14.11      8.89      7.36
# FamilyWork          0.14       0.16      0.22      0.69      0.55      0.25
# Unemployment        8.19       6.68     10.80      4.86     15.58      7.33
#
# cluster              6
# CensusId      65979.11
# TotalPop      68210.99
# Men           32972.12
# Women         35238.87
# Hispanic         96.24
# White             3.01
# Black             0.18
# Native            0.19
# Asian             0.16
# Pacific           0.01
# Citizen       44844.79
# Income        20857.69
# IncomePerCap  10879.42
# Poverty          45.62
# ChildPoverty     56.40
# Professional     28.28
# Service          22.80
# Office           24.99
# Construction     12.03
# Production       11.91
# Drive            82.42
# Carpool           8.82
# Transit           1.01
# Walk              3.69
# OtherTransp       1.62
# WorkAtHome        2.44
# MeanCommute      27.14
# Employed      22587.30
# PrivateWork      65.62
# PublicWork       26.09
# SelfEmployed      8.13
# FamilyWork        0.16
# Unemployment     17.60

# %%
# Analyze the results
for col in X_columns:
    print(col)
    for cluster in set(kmeans.labels_):
        plt.hist(df_results[df_results['cluster']==cluster][col], label=str(cluster), alpha=0.3, bins=20)
    plt.legend()
    plt.show()
# Out:
# TotalPop
# Men
# Women
# Hispanic
# White
# Black
# Native
# Asian
# Pacific
# Citizen
# Income
# IncomePerCap
# Poverty
# ChildPoverty
# Professional
# Service
# Office
# Construction
# Production
# Drive
# Carpool
# Transit
# Walk
# OtherTransp
# WorkAtHome
# MeanCommute
# Employed
# PrivateWork
# PublicWork
# SelfEmployed
# FamilyWork
# Unemployment

# %% [markdown]
# # Model Evaluation

# %%
centroids = []
for cluster in sorted(set(kmeans.labels_)):
    centroids.append(df_results[df_results['cluster']==cluster][X_columns].mean().values)
print(sum(sum(euclidean_distances(centroids, centroids))))

distances = 0
for cluster in sorted(set(kmeans.labels_)):
    centroid = df_results[df_results['cluster']==cluster][X_columns].mean().values
    distances += (sum(euclidean_distances(df_results[df_results['cluster']==cluster][X_columns].values, centroid.reshape(1, -1))))[0]
print(distances)
# Out:
# 22532393.6995
# 309595093.241

# %%
inertia = []
for k in range(2, 100):
    kmeans = KMeans(n_clusters=k).fit(df_norm.values)
    inertia.append(kmeans.inertia_)
plt.plot(inertia)
plt.show()
